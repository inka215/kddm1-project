# %%
! pip install wbgapi
! pip install pandas
! pip install matplotlib
! pip install scipy

# %%
import wbgapi as wb
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
scouting_notes = pd.read_csv('Data/hockey_scouting_notes.csv')
scouting_notes = scouting_notes.dropna()
scouting_notes.head()
# Out:
#    international_id    position dominant_hand experience_level  years_played  \
# 0              2991     defense          left          veteran           8.0
# 1              3042  right wing         right          veteran           0.0
# 2              3761  right wing         right          veteran           0.0
# 5              7096      goalie          left        sophomore           0.0
# 9              5118  right wing          left          veteran          12.0
#
#    years_pro                                        scout_notes
# 0        8.0  effort varies throughout the game, awkward str...
# 1        0.0  a consistent performer who can be counted on i...
# 2        0.0                          late support on breakouts
# 5        0.0  reliable shift to shift consistency, has a sec...
# 9        3.0                 raw skillset with strong potential
